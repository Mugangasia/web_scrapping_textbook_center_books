# %% [markdown]
# ### Imports

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np

# %% [markdown]
# ### HTTP Request
# *Store Website inside a variable*

# %%
website = "https://textbookcentre.com/catalogue/category/books/"

# %% [markdown]
# *Get Request*

# %%
response = requests.get(website)

# %% [markdown]
# *Status Code*

# %%
response.status_code
# Out:
# 200

# %% [markdown]
# *Soup Object*

# %%
soup = BeautifulSoup(response.content, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en" prefix="og: http://ogp.me/ns# product: http://ogp.me/ns/product#">
# <head>
# <title>
#     Books |
#      Text Book Centre
#
# </title>
# <meta charset="utf-8"/>
# <meta content="width=device-width, minimum-scale=0.25, maximum-scale=1.6, initial-scale=1.0" name="viewport"/>
# <meta content="yes" name="apple-mobile-web-app-capable"/>
# <meta content="
#
# " name="description"/>
# <link href="/static/img/favicon.166766220486.png" rel="icon" type="image/png"/>
# <link href="https://fonts.googleapis.com/css?family=Lato:400,700&amp;subset=latin-ext" rel="stylesheet"/>
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#     new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#     j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#     'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#     })(window,document,'script','dataLayer','GTM-NRV96SJ');</script>
# <meta content="Books" property="og:title"/>
# <meta content="website" property="og:type"/>
# <meta content="https://textbookcentre.com/catalogue/category/books/" property="og:url"/>
# <meta content="https://textbookcentre.com/media/categories/05_General_Books.jpg" property="og:image"/>
# <meta content="Text Book Centre" property="og:site_name"/>
# <link href="/static/webpack_bundles/main.4bebda023f4b.css" rel="stylesheet" type="text/css">
# <!-- dsp.idma Pixel Code -->
# <script>
#                 	!function(f,e,t,u,n,s,p) {if(f.esk)return;n=f.esk=function(){n.callMethod?n.callMethod.apply(n,arguments):n.queue.push(arguments)};if(!f.___esk)f.___esk=n;n.push=n;n.loaded=!0;n.queue=[];s=e.createElement(t);s.async=!0;s.src=u;p=e.getElementsByTagName(t)[0];p.parentNode.insertBefore(s,p)}(window,document,'script', 'https://dsp.idma.digital/r/AIfjbw_3-wbP76JTnJ5FiID4AysKBpizv2JQ1uOsNAhiYmY1OGY0Mzc3OGIyYjkw/assets/js/e/gtr.min.js?_=0.0.0.3');
#                 	esk('init', '29097');
#                 </script>
# <!-- End dsp.idma Pixel Code -->
# </link></head>
# <body class="" id="default">
# <div class="page">
# <header class="page-header">
# <div class="navbar navbar-expand-lg header-top-bar header-top-bar--main">
# <div class="container">
# <div class="header-site d-flex">
# <a class="nav-link active" href="//textbookcentre.com">TBC Home</a>
# <a class="nav-link" href="//ebooks.textbookcentre.com">Digital Books</a>
# <a class="nav-link" href="/tbc-kids/">TBC Kids</a>
# <a class="nav-link" href="https://textbookcentre.com/need-help-buying-online/">Need Help Shopping Online?</a>
# <a class="nav-link d-none d-md-block" href="//textbookcentre.com/stores/">TBC Branches</a>
# </div>
# <div class="header-contact ml-auto collapse navbar-collapse justify-content-end" id="header-contact">
# <a class="nav-link" href="tel:+254111011300">
# <svg class="icon icon-phone" role="presentation">
# <use href="/static/regulus_oscar/svg/icons.8a287fcd2acc.svg#phone"></use>
# </svg>
#  Call us! 0111 011300</a>
# </div>
# <a class="nav-link d-lg-none" data-target="#header-contact" data-toggle="collapse" href="#">
# <svg class="icon icon-phone" role="presentation">
# <use href="/static/regulus_oscar/svg/icons.8a287fcd2acc.svg#phone"></use>
# </svg>
# </a>
# </div>
# </div>
# <div class="header-main clearfix">
# <div class="container">
# <div class="header-menu-mobile">
# <a class="bg-primary text-white d-flex align-items-center" href="/"><img alt="Text Book Centre" class="img-fluid header-logo" src="/static/img/logo-condensed.fcfdd613d4ce.svg"/><span class="px-2">Text Book Centre</span></a>
# <div class="header-menu-basket">
# <a class="btn btn-light btn-sm header-basket-btn" href="/basket/">
# <svg class="icon icon-basket" role="presentation">
# <use href="/static/regulus_oscar/svg/icons.8a287fcd2acc.svg#basket"></use>
# </svg>
# </a>
# <span class="badge badge-pill header-basket-quantity"></span>
# </div>
# </div>
# <div class="row align-items-start">
# <div class="header-brand col-lg-2">
# <h1>
# <a href="/">
# <img alt="Text Book Centre" class="img-fluid header-logo" src="/static/img/logo.4a06b1d89d38.svg"/>
# <span class="sr-only">Text Book Centre</span>
# </a>
# </h1>
# </div>
# <div class="col-12 col-lg-8 js-header-search">
# <div class="d-flex">
# <div class="d-lg-none mr-3">
# <button aria-controls="navbar-menu" aria-expanded="false" aria-label="Toggle navigation" class="btn tbc-navbar-toggler collapsed js-toggler-animate" data-target="#navbar-menu" data-toggle="collapse" type="button">
# <span></span>
# <span></span>
# <span></span>
# </button>
# </div>
# <div class="header-search" id="header-search">
# <form action="/search/" class="form-inline" data-search-url="/search/" data-suggest-url="/catalogue/search/suggest/" id="header-search-form" method="get">
# <div class="input-group">
# <input autocomplete="off" class="form-control input-search typeahead" id="id_q" name="q" placeholder="Search for products" required="required" tabindex="1" type="search"/>
# <div class="input-group-append">
# <button class="btn btn-icon btn-primary" type="submit">
# <svg class="icon icon-search" role="presentation">
# <use href="/static/regulus_oscar/svg/icons.8a287fcd2acc.svg#search"></use>
# </svg>
# </button>
# </div>
# </div>
# </form>
# </div>
# </div>
# <nav class="navbar navbar-expand-lg header-menu">
# <div class="collapse navbar-collapse" id="navbar-menu">
# <div class="navbar-nav nav-fill w-100">
# <div class="d-lg-none">
# <h3 class="menu-section-header">My Text Book Centre Account</h3>
# <div class="nav-item"><a class="nav-link" href="/accounts/login/">
# <svg class="icon icon-account" role="presentation">
# <use href="/static/regulus_oscar/svg/icons.8a287fcd2acc.svg#account"></use>
# </svg>
# Login
#                 </a></div>
# </div>
# <h3 class="menu-section-header">Shop by category</h3>
# <div class="nav-item dropdown">
# <a class="nav-link dropdown-toggle" data-toggle="dropdown" href="/catalogue/category/text-books/">
# <span class="category-icon">
# <img alt="" class="img-fluid" src="/media/cache/ff/92/ff9262540af9a936669030c7e7fb0100.jpg"/>
# </span>
#                     Educational Books
#                 </a>
# <div class="dropdown-menu">
# <a class="dropdown-item" href="/catalogue/category/text-books/pre-primary-ecde/">Pre-Primary &amp; ECDE</a>
# <a class="dropdown-item" href="/catalogue/category/text-books/competency-based-curriculum/">Competency Based Curriculum</a>
# <a class="dropdown-item" href="/catalogue/category/text-books/gcseigcse/">International Curriculum</a>
# <a class="dropdown-item" href="/catalogue/category/text-books/primary-school/">Primary School</a>
# <a class="dropdown-item" href="/catalogue/category/text-books/secondary-school/">Secondary School</a>
# <a class="dropdown-item" href="/catalogue/category/text-books/higher-education/">Higher Education</a>
# </div></div>
# <div class="nav-item dropdown active">
# <a class="nav-link dropdown-toggle" data-toggle="dropdown" href="/catalogue/category/books/">
# <span class="category-icon">
# <img alt="" class="img-fluid" src="/media/cache/46/a2/46a28b8732c93ec3b3c1c6c450f11c9f.jpg"/>
# </span>
#                     Books
#                 </a>
# <div class="dropdown-menu">
# <a class="dropdown-item" href="/catalogue/category/books/cards-gift-bags-boxes/">Cards, Gift bags &amp; boxes</a>
# <a class="dropdown-item" href="/catalogue/category/books/children/">Children's Books</a>
# <a class="dropdown-item" href="/catalogue/category/books/childrens-teenage-series/">Teenage &amp; Young Adults</a>
# <a class="dropdown-item" href="/catalogue/category/books/novels/">Novels</a>
# <a class="dropdown-item" href="/catalogue/category/books/motivation-self-help/">Motivation &amp; Self Help</a>
# <a class="dropdown-item" href="/catalogue/category/books/biographies/">Biographies</a>
# <a class="dropdown-item" href="/catalogue/category/books/cookery/">Cookery</a>
# <a class="dropdown-item" href="/catalogue/category/books/africana/">Africana</a>
# <a class="dropdown-item" href="/catalogue/category/books/reference/">Reference</a>
# <a class="dropdown-item" href="/catalogue/category/books/travel/">Travel</a>
# <a class="dropdown-item" href="/catalogue/category/books/health-lifestyle/">Health &amp; Lifestyle</a>
# <a class="dropdown-item" href="/catalogue/category/books/pregnancy-child-care/">Pregnancy &amp; Child Care</a>
# <a class="dropdown-item" href="/catalogue/category/books/spirituality-beliefs/">Spirituality &amp; Beliefs</a>
# <a class="dropdown-item" href="/catalogue/category/books/science-fiction/">Science Fiction</a>
# <a class="dropdown-item" href="/catalogue/category/books/plays/">Plays</a>
# <a class="dropdown-item" href="/catalogue/category/books/people-and-culture/">People and Culture</a>
# <a class="dropdown-item" href="/catalogue/category/books/general/">General</a>
# <a class="dropdown-item" href="/catalogue/category/books/religion/">Religion</a>
# <a class="dropdown-item" href="/catalogue/category/books/family-relationships/">Family &amp; Relationships</a>
# <a class="dropdown-item" href="/catalogue/category/books/education/">Education</a>
# <a class="dropdown-item" href="/catalogue/category/books/economics/">Economics</a>
# <a class="dropdown-item" href="/catalogue/category/books/politics/">Politics</a>
# <a class="dropdown-item" href="/catalogue/category/books/photography/">Photography</a>
# <a class="dropdown-item" href="/catalogue/category/books/memoir/">Memoir</a>
# <a class="dropdown-item" href="/catalogue/category/books/history/">History</a>
# <a class="dropdown-item" href="/catalogue/category/books/comics/">Comics</a>
# <a class="dropdown-item" href="/catalogue/category/books/classics/">Classics</a>
# <a class="dropdown-item" href="/catalogue/category/books/home-garden/">Home &amp; Garden</a>
# <a class="dropdown-item" href="/catalogue/category/books/sports-hobbies/">Sports &amp; Hobbies</a>
# <a class="dropdown-item" href="/catalogue/category/books/science/">Science</a>
# <a class="dropdown-item" href="/catalogue/category/books/pet-pet-care/">Pet &amp; Pet Care</a>
# <a class="dropdown-item" href="/catalogue/category/books/age-9-12-years/">Age 9-12 Years</a>
# <a class="dropdown-item" href="/catalogue/category/books/english-language/">English Language</a>
# <a class="dropdown-item" href="/catalogue/category/books/interactive-activity-books-packs/">Interactive &amp; Activity Books &amp; Packs</a>
# <a class="dropdown-item" href="/catalogue/category/books/picture-storybooks/">Picture Storybooks</a>
# <a class="dropdown-item" href="/catalogue/category/books/modern-contemporary-fiction-post-c-1945/">Modern &amp; Contemporary Fiction (Post C 1945)</a>
# <a class="dropdown-item" href="/catalogue/category/books/general-fiction-childrens-teenage/">General Fiction (Children's / Teenage)</a>
# <a class="dropdown-item" href="/catalogue/category/books/dinosaurs-prehistoric-world-childrens-teenage/">Dinosaurs &amp; Prehistoric World (Children's / Teenage)</a>
# <a class="dropdown-item" href="/catalogue/category/books/space-childrens-teenage/">Space (Children's / Teenage)</a>
# <a class="dropdown-item" href="/catalogue/category/books/football-soccer-childrens-teenage/">Football / Soccer (Children's / Teenage)</a>
# <a class="dropdown-item" href="/catalogue/category/books/coping-with-illness-specific-conditions/">Coping With Illness &amp; Specific Conditions</a>
# <a class="dropdown-item" href="/catalogue/category/books/political-leaders-leadership/">Political Leaders &amp; Leadership</a>
# <a class="dropdown-item" href="/catalogue/category/books/thrillers-childrens-teenage/">Thrillers (Children's / Teenage)</a>
# <a class="dropdown-item" href="/catalogue/category/books/cooking-food-childrens-teenage/">Cooking &amp; Food (Children's / Teenage)</a>
# <a class="dropdown-item" href="/catalogue/category/books/political-science-theory/">Political Science &amp; Theory</a>
# <a class="dropdown-item" href="/catalogue/category/books/adventure-stories-childrens-teenage/">Adventure Stories (Children's / Teenage)</a>
# <a class="dropdown-item" href="/catalogue/category/books/school-stories-childrens-teenage/">School Stories (Children's / Teenage)</a>
# <a class="dropdown-item" href="/catalogue/category/books/fantasy-magical-realism-childrens-teenage/">Fantasy &amp; Magical Realism (Children's / Teenage)</a>
# <a class="dropdown-item" href="/catalogue/category/books/international-relations/">International Relations</a>
# <a class="dropdown-item" href="/catalogue/category/books/horror-ghost-stories-chillers-childrens-teenage/">Horror &amp; Ghost Stories, Chillers (Children's / Teenage)</a>
# <a class="dropdown-item" href="/catalogue/category/books/hobbies-quizzes-games-childrens-teenage/">Hobbies, Quizzes &amp; Games (Children's / Teenage)</a>
# <a class="dropdown-item" href="/catalogue/category/books/general-cookery-recipes/">General Cookery &amp; Recipes</a>
# <a class="dropdown-item" href="/catalogue/category/books/romance-relationships-stories-childrens-teenage/">Romance &amp; Relationships Stories (Children's / Teenage)</a>
# <a class="dropdown-item" href="/catalogue/category/books/classic-fiction-childrens-teenage/">Classic Fiction (Children's / Teenage)</a>
# <a class="dropdown-item" href="/catalogue/category/books/classic-fiction-pre-c-1945/">Classic Fiction (Pre C 1945)</a>
# </div></div>
# <div class="nav-item dropdown">
# <a class="nav-link dropdown-toggle" data-toggle="dropdown" href="/catalogue/category/computers-accessories/">
# <span class="category-icon">
# <img alt="" class="img-fluid" src="/media/cache/fe/60/fe602476885f3e2ba3782b905567b15c.jpg"/>
# </span>
#                     Computers &amp; Electronics
#                 </a>
# <div class="dropdown-menu">
# <a class="dropdown-item" href="/catalogue/category/computers-accessories/laptops/">Laptops</a>
# <a class="dropdown-item" href="/catalogue/category/computers-accessories/desktops/">Desktops &amp; Monitors</a>
# <a class="dropdown-item" href="/catalogue/category/computers-accessories/printers-scanners/">Printers &amp; Scanners</a>
# <a class="dropdown-item" href="/catalogue/category/computers-accessories/printer-supplies/">Printer Supplies</a>
# <a class="dropdown-item" href="/catalogue/category/computers-accessories/accessories/">Accessories &amp; Peripherals</a>
# <a class="dropdown-item" href="/catalogue/category/computers-accessories/storage-media/">Storage Devices</a>
# <a class="dropdown-item" href="/catalogue/category/computers-accessories/tablets-smartwatches/">Tablets &amp; Smartwatches</a>
# <a class="dropdown-item" href="/catalogue/category/computers-accessories/headphones-earphones/">Headphones &amp; Earphones</a>
# <a class="dropdown-item" href="/catalogue/category/computers-accessories/camera/">Camera</a>
# <a class="dropdown-item" href="/catalogue/category/computers-accessories/calculators/">Calculators</a>
# <a class="dropdown-item" href="/catalogue/category/computers-accessories/speakers/">Speakers</a>
# <a class="dropdown-item" href="/catalogue/category/computers-accessories/power-backup/">Power Backup</a>
# <a class="dropdown-item" href="/catalogue/category/computers-accessories/peripherals/">Peripherals</a>
# <a class="dropdown-item" href="/catalogue/category/computers-accessories/software/">Software</a>
# <a class="dropdown-item" href="/catalogue/category/computers-accessories/lcd-projectors/">LCD Projectors</a>
# </div></div>
# <div class="nav-item dropdown">
# <a class="nav-link dropdown-toggle" data-toggle="dropdown" href="/catalogue/category/stationery/">
# <span class="category-icon">
# <img alt="" class="img-fluid" src="/media/cache/3a/46/3a460126b23f64fb3e9cd7100f585cc1.jpg"/>
# </span>
#                     Stationery
#                 </a>
# <div class="dropdown-menu">
# <a class="dropdown-item" href="/catalogue/category/stationery/office-supplies/">Office Stationery</a>
# <a class="dropdown-item" href="/catalogue/category/stationery/miscellaneous-stationery/">School Stationery</a>
# <a class="dropdown-item" href="/catalogue/category/stationery/desk-items/">Desk Items</a>
# <a class="dropdown-item" href="/catalogue/category/stationery/exercise-books/">Exercise Books</a>
# <a class="dropdown-item" href="/catalogue/category/stationery/files/">Files &amp; Binders</a>
# <a class="dropdown-item" href="/catalogue/category/stationery/markers/">Markers</a>
# <a class="dropdown-item" href="/catalogue/category/stationery/note-books-diaries/">Note Books &amp; Diaries</a>
# <a class="dropdown-item" href="/catalogue/category/stationery/pens-pencils/">Pens, Pencils &amp; Pouches</a>
# <a class="dropdown-item" href="/catalogue/category/stationery/library-items/">Library Items</a>
# <a class="dropdown-item" href="/catalogue/category/stationery/accounting-books/">Accounting Books</a>
# <a class="dropdown-item" href="/catalogue/category/stationery/technical-items/">Technical Items</a>
# <a class="dropdown-item" href="/catalogue/category/stationery/writing-pads/">Writing Pads</a>
# <a class="dropdown-item" href="/catalogue/category/stationery/cards/">Cards &amp; Gifting</a>
# <a class="dropdown-item" href="/catalogue/category/stationery/Covid-19-face-masks/">Face Masks</a>
# </div></div>
# <div class="nav-item dropdown">
# <a class="nav-link dropdown-toggle" data-toggle="dropdown" href="/catalogue/category/art-supplies/">
# <span class="category-icon">
# <img alt="" class="img-fluid" src="/media/cache/9a/f6/9af621471b7f05635ed572f98fb9b268.jpg"/>
# </span>
#                     Art Supplies
#                 </a>
# <div class="dropdown-menu">
# <a class="dropdown-item" href="/catalogue/category/art-supplies/art-craft/">Art &amp; Craft</a>
# <a class="dropdown-item" href="/catalogue/category/art-supplies/kids-colouring-books/">Kids Colouring Books</a>
# <a class="dropdown-item" href="/catalogue/category/art-supplies/adult-coloring-books/">Adult Coloring Books</a>
# <a class="dropdown-item" href="/catalogue/category/art-supplies/adhesives/">Adhesives</a>
# <a class="dropdown-item" href="/catalogue/category/art-supplies/brushes/">Brushes</a>
# <a class="dropdown-item" href="/catalogue/category/art-supplies/canvas/">Canvas</a>
# <a class="dropdown-item" href="/catalogue/category/art-supplies/paints-mediums/">Paints &amp; Mediums</a>
# <a class="dropdown-item" href="/catalogue/category/art-supplies/pen-makers-inks/">Pen, Markers &amp; Inks</a>
# <a class="dropdown-item" href="/catalogue/category/art-supplies/pastels-crayons/">Pastels &amp; Crayons</a>
# <a class="dropdown-item" href="/catalogue/category/art-supplies/adult-coloring/">Adult Coloring</a>
# <a class="dropdown-item" href="/catalogue/category/art-supplies/pens-charcoal/">Pencils &amp; Charcoal</a>
# <a class="dropdown-item" href="/catalogue/category/art-supplies/sculpture-modeling/">Sculpture &amp; Modeling</a>
# <a class="dropdown-item" href="/catalogue/category/art-supplies/sketchbooks-paper/">Sketchbooks,Sketch Pads &amp; Paper</a>
# <a class="dropdown-item" href="/catalogue/category/art-supplies/pens-markers-inks/">Tools &amp; Accessories</a>
# <a class="dropdown-item" href="/catalogue/category/art-supplies/handicrafts-childrens-teenage/">Handicrafts (Children's / Teenage)</a>
# <a class="dropdown-item" href="/catalogue/category/art-supplies/easels/">Easels</a>
# </div></div>
# <div class="nav-item dropdown">
# <a class="nav-link dropdown-toggle" data-toggle="dropdown" href="/catalogue/category/toys-board-games/">
# <span class="category-icon">
# <img alt="" class="img-fluid" src="/media/cache/48/92/48922270cbb283034fd02678a0ab604b.jpg"/>
# </span>
#                     Toys &amp; Board Games
#                 </a>
# <div class="dropdown-menu">
# <a class="dropdown-item" href="/catalogue/category/toys-board-games/toys/">Toys</a>
# <a class="dropdown-item" href="/catalogue/category/toys-board-games/board-games/">Board Games</a>
# <a class="dropdown-item" href="/catalogue/category/toys-board-games/puzzles/">Puzzles</a>
# </div></div>
# <div class="nav-item category-menu-main-extra">
# <a class="nav-link" href="/catalogue/on-sale/">On Sale</a>
# </div>
# <div class="d-lg-none">
# <h3 class="menu-section-header">Our Channels</h3>
# <div class="nav-item"><a class="nav-link" href="//textbookcentre.com">
# <svg class="icon icon-home" role="presentation">
# <use href="/static/regulus_oscar/svg/icons.8a287fcd2acc.svg#home"></use>
# </svg>
#  Text Book Centre Home</a></div>
# <div class="nav-item"><a class="nav-link" href="//ebooks.textbookcentre.com">
# <svg class="icon icon-mobile" role="presentation">
# <use href="/static/regulus_oscar/svg/icons.8a287fcd2acc.svg#mobile"></use>
# </svg>
#  Digital Books</a></div>
# <div class="nav-item"><a class="nav-link" href="//textbookcentre.com/stores/">
# <svg class="icon icon-store" role="presentation">
# <use href="/static/regulus_oscar/svg/icons.8a287fcd2acc.svg#store"></use>
# </svg>
#  TBC Branches</a></div>
# <div class="nav-item"><a class="nav-link" href="//textbookcentre.com/contact/">
# <svg class="icon icon-phone" role="presentation">
# <use href="/static/regulus_oscar/svg/icons.8a287fcd2acc.svg#phone"></use>
# </svg>
#  Contact Us</a></div>
# </div>
# </div>
# </div>
# </nav>
# </div>
# <div class="col-lg-2 d-none d-lg-block text-lg-right">
# <div class="dropdown d-inline-block">
# <a class="nav-link dropdown-toggle px-1" data-toggle="dropdown" href="#">
#                         My Account
#                     </a>
# <div class="dropdown-menu">
# <a class="dropdown-item" href="/accounts/login/">Sign in or register</a>
# </div>
# </div>
# <div class="header-basket d-inline-block">
# <div class="btn-group" role="group">
# <button aria-expanded="false" aria-haspopup="true" class="btn btn-link" data-toggle="dropdown" id="header-basket-btn" type="button">
# <svg class="icon icon-basket" role="presentation">
# <use href="/static/regulus_oscar/svg/icons.8a287fcd2acc.svg#basket"></use>
# </svg>
# </button>
# <div aria-labelledby="header-basket-btn" class="dropdown-menu dropdown-menu-right dropdown-basket" id="header-basket-dropdown">
# <div class="basket-compact" data-csrf-token="cU2lf588ijLELyEPqYYuNeRCQWfkeKs5otJVzRHRZZV0H0qTruflzrp6YFtnDEk9">
# <p class="text-center px-2">Your basket is empty!</p>
# <div class="basket-lines pt-2">
# </div>
# <div class="basket-details">
# <div class="basket-total total">
# <span class="amount-label">Total</span>
# <span class="amount-value">KES 0</span>
# </div>
# </div>
# </div>
# </div>
# </div>
# <span class="badge badge-pill header-basket-quantity"></span>
# </div>
# </div>
# </div>
# </div>
# </div>
# </header>
# <main class="page-main">
# <div class="container">
# <nav aria-label="breadcrumb" class="page-breadcrumb">
# <ol class="breadcrumb">
# <li class="breadcrumb-item"><a href="/">Home</a></li>
# <li class="breadcrumb-item active">Books</li>
# </ol>
# </nav>
# <script id="breadcrumb_schema" type="application/ld+json">{"@context": "http://schema.org", "@type": "BreadcrumbList", "itemListElement": [{"@type": "ListItem", "position": 1, "item": {"@id": "https://textbookcentre.com/", "url": "https://textbookcentre.com/", "name": "Home"}}, {"@type": "ListItem", "position": 2, "item": {"@id": "https://textbookcentre.com/catalogue/category/books/", "url": "https://textbookcentre.com/catalogue/category/books/", "name": "Books"}}]}</script>
# <div id="messages">
# </div>
# <section class="block block-featured_products">
# <h3 class="subheading"><span class="subheading-text">Featured Books</span></h3>
# <div class="product-list row">
# <div class="product-item d-flex col-6 col-sm-4 col-lg-2">
# <div class="card product-card">
# <a href="/catalogue/no-picnic-on-mount-kenya_231494/">
# <div class="product-card-img-container">
# <img alt="No Picnic on Mount Kenya" class="img-fluid card-img-top product-card-img" loading="lazy" src="/media/cache/0e/a4/0ea4a55f8998e1c34d6a66af65a88205.jpg" srcset="/media/cache/0e/a4/0ea4a55f8998e1c34d6a66af65a88205.jpg 1x, /media/cache/0e/a4/0ea4a55f8998e1c34d6a66af65a88205@2x.jpg 2x"/>
# </div>
# <div class="card-body product-card-body mb-2">
# <div>
# <h5 class="card-title product-card-name">No Picnic on Mount Kenya</h5>
# <span class="text-muted small">Felice Benuzzi</span>
# </div>
# <div class="w-100 d-flex justify-content-between align-items-center">
# <div class="stockrecord-prices">
# <span class="stockrecord-price-current">
#
#                     KES 1,690
#
#             </span>
# </div>
# <div class="product-card--rating small text-muted">
#                             5 <div class="catalogue-reviews-star active"><span class="star-filled">
# <svg class="icon icon-star" role="presentation">
# <use href="/static/regulus_oscar/svg/icons.8a287fcd2acc.svg#star"></use>
# </svg>
# </span></div>
# </div>
# </div>
# </div>
# </a>
# <form action="/basket/add/231494/" class="js-basket-add-form downloadable" data-api-action="/basket/api/add-product/" data-product-track-stock="True" method="post">
# <button class="btn btn-light btn-disabled btn-block" disabled="">Out of stock</button>
# <input name="csrfmiddlewaretoken" type="hidden" value="NT1CCkrc4NZ5dJdmDd4BTwaqQ3g2Em1IvDDjmEH9j4pmcNpIOpJfFSA1dwV4782r"/>
# </form>
# </div>
# </div>
# <div class="product-item d-flex col-6 col-sm-4 col-lg-2">
# <div class="card product-card">
# <a href="/catalogue/finding-me-a-memoir-the-instant-sunday-times-1-new-york-times-bestseller_324105/">
# <div class="product-card-img-container">
# <img alt="Finding Me: A Memoir - THE INSTANT SUNDAY TIMES &amp; #1 NEW YORK TIMES BESTSELLER" class="img-fluid card-img-top product-card-img" loading="lazy" src="/media/cache/d7/91/d79181ff8f97ae6b92c9f8631889c15b.jpg" srcset="/media/cache/d7/91/d79181ff8f97ae6b92c9f8631889c15b.jpg 1x, /media/cache/d7/91/d79181ff8f97ae6b92c9f8631889c15b@2x.jpg 2x"/>
# </div>
# <div class="card-body product-card-body mb-2">
# <div>
# <h5 class="card-title product-card-name">Finding Me: A Memoir - THE INSTANT SUNDAY …</h5>
# <span class="text-muted small">Viola Davis</span>
# </div>
# <div class="w-100 d-flex justify-content-between align-items-center">
# <div class="stockrecord-prices">
# <span class="stockrecord-price-current">
#
#                     KES 2,250
#
#             </span>
# </div>
# </div>
# </div>
# </a>
# <form action="/basket/add/324105/" class="js-basket-add-form downloadable" data-api-action="/basket/api/add-product/" data-product-track-stock="True" method="post">
# <input name="product" type="hidden" value="324105"/>
# <input name="quantity" type="hidden" value="1"/>
# <button class="btn btn-light_accent mx-auto btn-block">Add to basket</button>
# <input name="csrfmiddlewaretoken" type="hidden" value="NT1CCkrc4NZ5dJdmDd4BTwaqQ3g2Em1IvDDjmEH9j4pmcNpIOpJfFSA1dwV4782r"/>
# </form>
# </div>
# </div>
# <div class="product-item d-flex col-6 col-sm-4 col-lg-2">
# <div class="card product-card">
# <a href="/catalogue/the-power-of-habit-why-we-do-what-we-do-and-how-to-change_12247/">
# <div class="product-card-img-container">
# <img alt="The Power of Habit: Why we do what we do and how to change" class="img-fluid card-img-top product-card-img" loading="lazy" src="/media/cache/e7/43/e743cb825333e3d2d1ee52ed0bb7a5f0.jpg" srcset="/media/cache/e7/43/e743cb825333e3d2d1ee52ed0bb7a5f0.jpg 1x, /media/cache/e7/43/e743cb825333e3d2d1ee52ed0bb7a5f0@2x.jpg 2x"/>
# </div>
# <div class="card-body product-card-body mb-2">
# <div>
# <h5 class="card-title product-card-name">The Power of Habit: Why we do what …</h5>
# <span class="text-muted small">Charles Duhigg</span>
# </div>
# <div class="w-100 d-flex justify-content-between align-items-center">
# <div class="stockrecord-prices">
# <span class="stockrecord-price-current">
#
#                     KES 1,150
#
#             </span>
# </div>
# <div class="product-card--rating small text-muted">
#                             5 <div class="catalogue-reviews-star active"><span class="star-filled">
# <svg class="icon icon-star" role="presentation">
# <use href="/static/regulus_oscar/svg/icons.8a287fcd2acc.svg#star"></use>
# </svg>
# </span></div>
# </div>
# </div>
# </div>
# </a>
# <form action="/basket/add/12247/" class="js-basket-add-form downloadable" data-api-action="/basket/api/add-product/" data-product-track-stock="True" method="post">
# <input name="product" type="hidden" value="12247"/>
# <input name="quantity" type="hidden" value="1"/>
# <button class="btn btn-light_accent mx-auto btn-block">Add to basket</button>
# <input name="csrfmiddlewaretoken" type="hidden" value="NT1CCkrc4NZ5dJdmDd4BTwaqQ3g2Em1IvDDjmEH9j4pmcNpIOpJfFSA1dwV4782r"/>
# </form>
# </div>
# </div>
# <div class="product-item d-flex col-6 col-sm-4 col-lg-2">
# <div class="card product-card">
# <a href="/catalogue/hot-hippo-kenn_11973/">
# <div class="product-card-img-container">
# <img alt="Hot Hippo (Kenn)" class="img-fluid card-img-top product-card-img" loading="lazy" src="/media/cache/17/a7/17a73cb4d36b722ffe2ea99b71db9137.jpg" srcset="/media/cache/17/a7/17a73cb4d36b722ffe2ea99b71db9137.jpg 1x, /media/cache/17/a7/17a73cb4d36b722ffe2ea99b71db9137@2x.jpg 2x"/>
# </div>
# <div class="card-body product-card-body mb-2">
# <div>
# <h5 class="card-title product-card-name">Hot Hippo (Kenn)</h5>
# <span class="text-muted small">Mwenye Hadithi</span>
# </div>
# <div class="w-100 d-flex justify-content-between align-items-center">
# <div class="stockrecord-prices">
# <span class="stockrecord-price-current">
#
#                     KES 620
#
#             </span>
# </div>
# </div>
# </div>
# </a>
# <form action="/basket/add/11973/" class="js-basket-add-form downloadable" data-api-action="/basket/api/add-product/" data-product-track-stock="True" method="post">
# <input name="product" type="hidden" value="11973"/>
# <input name="quantity" type="hidden" value="1"/>
# <button class="btn btn-light_accent mx-auto btn-block">Add to basket</button>
# <input name="csrfmiddlewaretoken" type="hidden" value="NT1CCkrc4NZ5dJdmDd4BTwaqQ3g2Em1IvDDjmEH9j4pmcNpIOpJfFSA1dwV4782r"/>
# </form>
# </div>
# </div>
# <div class="product-item d-flex col-6 col-sm-4 col-lg-2">
# <div class="card product-card">
# <a href="/catalogue/becoming-michelle-obama-adapted-for-young-readers_308609/">
# <div class="product-card-img-container">
# <img alt="Becoming Michelle Obama Adapted for Young Readers" class="img-fluid card-img-top product-card-img" loading="lazy" src="/media/cache/3c/db/3cdb8f6d9a0182d41c62703a041b152e.jpg" srcset="/media/cache/3c/db/3cdb8f6d9a0182d41c62703a041b152e.jpg 1x, /media/cache/3c/db/3cdb8f6d9a0182d41c62703a041b152e@2x.jpg 2x"/>
# </div>
# <div class="card-body product-card-body mb-2">
# <div>
# <h5 class="card-title product-card-name">Becoming Michelle Obama Adapted for Young Readers</h5>
# <span class="text-muted small">Michelle Obama</span>
# </div>
# <div class="w-100 d-flex justify-content-between align-items-center">
# <div class="stockrecord-prices">
# <span class="stockrecord-price-current">
#
#                     KES 1,990
#
#             </span>
# </div>
# </div>
# </div>
# </a>
# <form action="/basket/add/308609/" class="js-basket-add-form downloadable" data-api-action="/basket/api/add-product/" data-product-track-stock="True" method="post">
# <button class="btn btn-light btn-disabled btn-block" disabled="">Out of stock</button>
# <input name="csrfmiddlewaretoken" type="hidden" value="NT1CCkrc4NZ5dJdmDd4BTwaqQ3g2Em1IvDDjmEH9j4pmcNpIOpJfFSA1dwV4782r"/>
# </form>
# </div>
# </div>
# <div class="product-item d-flex col-6 col-sm-4 col-lg-2">
# <div class="card product-card">
# <a href="/catalogue/amazon-unbound_315240/">
# <div class="product-card-img-container">
# <img alt="Amazon Unbound" class="img-fluid card-img-top product-card-img" loading="lazy" src="/media/cache/b5/f6/b5f6c2ccffbdea46c720a05574f1a994.jpg" srcset="/media/cache/b5/f6/b5f6c2ccffbdea46c720a05574f1a994.jpg 1x, /media/cache/b5/f6/b5f6c2ccffbdea46c720a05574f1a994@2x.jpg 2x"/>
# </div>
# <div class="card-body product-card-body mb-2">
# <div>
# <h5 class="card-title product-card-name">Amazon Unbound</h5>
# <span class="text-muted small">Brad Stone</span>
# </div>
# <div class="w-100 d-flex justify-content-between align-items-center">
# <div class="stockrecord-prices">
# <span class="stockrecord-price-current">
#
#                     KES 2,250
#
#             </span>
# </div>
# </div>
# </div>
# </a>
# <form action="/basket/add/315240/" class="js-basket-add-form downloadable" data-api-action="/basket/api/add-product/" data-product-track-stock="True" method="post">
# <input name="product" type="hidden" value="315240"/>
# <input name="quantity" type="hidden" value="1"/>
# <button class="btn btn-light_accent mx-auto btn-block">Add to basket</button>
# <input name="csrfmiddlewaretoken" type="hidden" value="NT1CCkrc4NZ5dJdmDd4BTwaqQ3g2Em1IvDDjmEH9j4pmcNpIOpJfFSA1dwV4782r"/>
# </form>
# </div>
# </div>
# </div>
# </section>
# <div class="row mb-3 justify-content-center">
# <div class="col-3 col-md-2 d-flex">
# <a class="card pb-2 d-flex text-center mb-1 small" href="/catalogue/category/books/cards-gift-bags-boxes/">
# <img alt="Cards, Gift bags &amp; boxes" class="img-fluid" src="/static/oscar/img/image_not_found.a102c3d37121.jpg"/>
# <span class="px-1 pt-1">Cards, Gift bags &amp; boxes</span>
# </a>
# </div>
# <div class="col-3 col-md-2 d-flex">
# <a class="card pb-2 d-flex text-center mb-1 small" href="/catalogue/category/books/children/">
# <img alt="Children's Books" class="img-fluid" src="/media/cache/92/d8/92d8231463fe36ed82172eb82dabd9ff.jpg"/>
# <span class="px-1 pt-1">Children's Books</span>
# </a>
# </div>
# <div class="col-3 col-md-2 d-flex">
# <a class="card pb-2 d-flex text-center mb-1 small" href="/catalogue/category/books/childrens-teenage-series/">
# <img alt="Teenage &amp; Young Adults" class="img-fluid" src="/media/cache/9c/a9/9ca90f97e0d3f63108ece63e40369a28.jpg"/>
# <span class="px-1 pt-1">Teenage &amp; Young Adults</span>
# </a>
# </div>
# <div class="col-3 col-md-2 d-flex">
# <a class="card pb-2 d-flex text-center mb-1 small" href="/catalogue/category/books/novels/">
# <img alt="Novels" class="img-fluid" src="/media/cache/6d/1d/6d1dce7482e5ab934074ce3cff38ade4.jpg"/>
# <span class="px-1 pt-1">Novels</span>
# </a>
# </div>
# <div class="col-3 col-md-2 d-flex">
# <a class="card pb-2 d-flex text-center mb-1 small" href="/catalogue/category/books/motivation-self-help/">
# <img alt="Motivation &amp; Self Help" class="img-fluid" src="/media/cache/43/cb/43cbc616c2e8f879898b8f10e69bdb68.jpg"/>
# <span class="px-1 pt-1">Motivation &amp; Self Help</span>
# </a>
# </div>
# <div class="col-3 col-md-2 d-flex">
# <a class="card pb-2 d-flex text-center mb-1 small" href="/catalogue/category/books/biographies/">
# <img alt="Biographies" class="img-fluid" src="/media/cache/cf/83/cf83d321e74a03f124ee8038dc1b03ca.jpg"/>
# <span class="px-1 pt-1">Biographies</span>
# </a>
# </div>
# <div class="col-3 col-md-2 d-md-none d-flex">
# <a class="card pb-2 d-flex text-center mb-1 small" href="/catalogue/category/books/cookery/">
# <img alt="Cookery" class="img-fluid" src="/media/cache/56/23/5623312b2e429a6daf07bb157a406563.jpg"/>
# <span class="px-1 pt-1">Cookery</span>
# </a>
# </div>
# <div class="col-3 col-md-2 d-md-none d-flex">
# <a class="card pb-2 d-flex text-center mb-1 small" href="/catalogue/category/books/africana/">
# <img alt="Africana" class="img-fluid" src="/media/cache/87/2f/872f8a94644bfe79021aa22eba5e1c10.jpg"/>
# <span class="px-1 pt-1">Africana</span>
# </a>
# </div>
# </div>
# <div class="row">
# <aside class="sidebar col-lg-3">
# <div class="collapse" id="filters">
# <div class="card filter">
# <div class="card-header filter-header">
# <span class="filter-header-text">Categories</span>
# </div>
# <div class="list-group list-group-flush filter-items filter-items--depth-0">
# <a class="list-group-item list-group-item-action active filter-item filter-item-active" data-category_id="82" href="/catalogue/category/books/"><span class="filter-name">Books</span></a>
# <div class="list-group list-group-flush filter-items">
# <a class="list-group-item list-group-item-action filter-item" data-category_id="3438" href="/catalogue/category/books/cards-gift-bags-boxes/"><span class="filter-name">Cards, Gift bags &amp; boxes</span><span class="badge badge-primary badge-pill filter-count">48</span></a>
# <a class="list-group-item list-group-item-action filter-item" data-category_id="86" href="/catalogue/category/books/children/"><span class="filter-name">Children's Books</span><span class="badge badge-primary badge-pill filter-count">2145</span></a>
# <a class="list-group-item list-group-item-action filter-item" data-category_id="87" href="/catalogue/category/books/childrens-teenage-series/"><span class="filter-name">Teenage &amp; Young Adults</span><span class="badge badge-primary badge-pill filter-count">453</span></a>
# <a class="list-group-item list-group-item-action filter-item" data-category_id="107" href="/catalogue/category/books/novels/"><span class="filter-name">Novels</span><span class="badge badge-primary badge-pill filter-count">1442</span></a>
# <a class="list-group-item list-group-item-action filter-item" data-category_id="85" href="/catalogue/category/books/motivation-self-help/"><span class="filter-name">Motivation &amp; Self Help</span><span class="badge badge-primary badge-pill filter-count">699</span></a>
# <a class="list-group-item list-group-item-action filter-item" data-category_id="84" href="/catalogue/category/books/biographies/"><span class="filter-name">Biographies</span><span class="badge badge-primary badge-pill filter-count">146</span></a>
# <a class="list-group-item list-group-item-action filter-item" data-category_id="114" href="/catalogue/category/books/cookery/"><span class="filter-name">Cookery</span><span class="badge badge-primary badge-pill filter-count">127</span></a>
# <a class="list-group-item list-group-item-action filter-item" data-category_id="83" href="/catalogue/category/books/africana/"><span class="filter-name">Africana</span><span class="badge badge-primary badge-pill filter-count">130</span></a>
# <a class="list-group-item list-group-item-action filter-item" data-category_id="118" href="/catalogue/category/books/reference/"><span class="filter-name">Reference</span><span class="badge badge-primary badge-pill filter-count">264</span></a>
# <a class="list-group-item list-group-item-action filter-item" data-category_id="112" href="/catalogue/category/books/travel/"><span class="filter-name">Travel</span><span class="badge badge-primary badge-pill filter-count">72</span></a>
# <a class="list-group-item list-group-item-action filter-item" data-category_id="115" href="/catalogue/category/books/health-lifestyle/"><span class="filter-name">Health &amp; Lifestyle</span><span class="badge badge-primary badge-pill filter-count">79</span></a>
# <a class="list-group-item list-group-item-action filter-item" data-category_id="110" href="/catalogue/category/books/pregnancy-child-care/"><span class="filter-name">Pregnancy &amp; Child Care</span><span class="badge badge-primary badge-pill filter-count">9</span></a>
# <a class="list-group-item list-group-item-action filter-item" data-category_id="111" href="/catalogue/category/books/spirituality-beliefs/"><span class="filter-name">Spirituality &amp; Beliefs</span><span class="badge badge-primary badge-pill filter-count">169</span></a>
# <a class="list-group-item list-group-item-action filter-item" data-category_id="312" href="/catalogue/category/books/science-fiction/"><span class="filter-name">Science Fiction</span><span class="badge badge-primary badge-pill filter-count">1</span></a>
# <a class="list-group-item list-group-item-action filter-item" data-category_id="310" href="/catalogue/category/books/plays/"><span class="filter-name">Plays</span><span class="badge badge-primary badge-pill filter-count">15</span></a>
# <a class="list-group-item list-group-item-action filter-item" data-category_id="309" href="/catalogue/category/books/people-and-culture/"><span class="filter-name">People and Culture</span><span class="badge badge-primary badge-pill filter-count">5</span></a>
# <a class="list-group-item list-group-item-action filter-item" data-category_id="307" href="/catalogue/category/books/general/"><span class="filter-name">General</span><span class="badge badge-primary badge-pill filter-count">310</span></a>
# <a class="list-group-item list-group-item-action filter-item" data-category_id="305" href="/catalogue/category/books/religion/"><span class="filter-name">Religion</span><span class="badge badge-primary badge-pill filter-count">1</span></a>
# <a class="list-group-item list-group-item-action filter-item" data-category_id="304" href="/catalogue/category/books/family-relationships/"><span class="filter-name">Family &amp; Relationships</span><span class="badge badge-primary badge-pill filter-count">16</span></a>
# <a class="list-group-item list-group-item-action filter-item" data-category_id="303" href="/catalogue/category/books/education/"><span class="filter-name">Education</span><span class="badge badge-primary badge-pill filter-count">29</span></a>
# <a class="list-group-item list-group-item-action filter-item" data-category_id="302" href="/catalogue/category/books/economics/"><span class="filter-name">Economics</span><span class="badge badge-primary badge-pill filter-count">28</span></a>
# <a class="list-group-item list-group-item-action filter-item" data-category_id="301" href="/catalogue/category/books/politics/"><span class="filter-name">Politics</span><span class="badge badge-primary badge-pill filter-count">23</span></a>
# <a class="list-group-item list-group-item-action filter-item" data-category_id="300" href="/catalogue/category/books/photography/"><span class="filter-name">Photography</span><span class="badge badge-primary badge-pill filter-count">6</span></a>
# <a class="list-group-item list-group-item-action filter-item" data-category_id="299" href="/catalogue/category/books/memoir/"><span class="filter-name">Memoir</span><span class="badge badge-primary badge-pill filter-count">3</span></a>
# <a class="list-group-item list-group-item-action filter-item" data-category_id="297" href="/catalogue/category/books/history/"><span class="filter-name">History</span><span class="badge badge-primary badge-pill filter-count">30</span></a>
# <a class="list-group-item list-group-item-action filter-item" data-category_id="296" href="/catalogue/category/books/comics/"><span class="filter-name">Comics</span><span class="badge badge-primary badge-pill filter-count">28</span></a>
# <a class="list-group-item list-group-item-action filter-item" data-category_id="113" href="/catalogue/category/books/classics/"><span class="filter-name">Classics</span><span class="badge badge-primary badge-pill filter-count">72</span></a>
# <a class="list-group-item list-group-item-action filter-item" data-category_id="116" href="/catalogue/category/books/home-garden/"><span class="filter-name">Home &amp; Garden</span><span class="badge badge-primary badge-pill filter-count">7</span></a>
# <a class="list-group-item list-group-item-action filter-item" data-category_id="117" href="/catalogue/category/books/sports-hobbies/"><span class="filter-name">Sports &amp; Hobbies</span><span class="badge badge-primary badge-pill filter-count">26</span></a>
# <a class="list-group-item list-group-item-action filter-item" data-category_id="119" href="/catalogue/category/books/science/"><span class="filter-name">Science</span><span class="badge badge-primary badge-pill filter-count">41</span></a>
# <a class="list-group-item list-group-item-action filter-item" data-category_id="120" href="/catalogue/category/books/pet-pet-care/"><span class="filter-name">Pet &amp; Pet Care</span><span class="badge badge-primary badge-pill filter-count">3</span></a>
# <a class="list-group-item list-group-item-action filter-item" data-category_id="1872" href="/catalogue/category/books/english-language/"><span class="filter-name">English Language</span><span class="badge badge-primary badge-pill filter-count">3</span></a>
# <a class="list-group-item list-group-item-action filter-item" data-category_id="1911" href="/catalogue/category/books/interactive-activity-books-packs/"><span class="filter-name">Interactive &amp; Activity Books &amp; Packs</span><span class="badge badge-primary badge-pill filter-count">2</span></a>
# <a class="list-group-item list-group-item-action filter-item" data-category_id="1928" href="/catalogue/category/books/picture-storybooks/"><span class="filter-name">Picture Storybooks</span><span class="badge badge-primary badge-pill filter-count">7</span></a>
# <a class="list-group-item list-group-item-action filter-item" data-category_id="1929" href="/catalogue/category/books/modern-contemporary-fiction-post-c-1945/"><span class="filter-name">Modern &amp; Contemporary Fiction (Post C 1945)</span><span class="badge badge-primary badge-pill filter-count">9</span></a>
# <a class="list-group-item list-group-item-action filter-item" data-category_id="1930" href="/catalogue/category/books/general-fiction-childrens-teenage/"><span class="filter-name">General Fiction (Children's / Teenage)</span><span class="badge badge-primary badge-pill filter-count">3</span></a>
# <a class="list-group-item list-group-item-action filter-item" data-category_id="1944" href="/catalogue/category/books/dinosaurs-prehistoric-world-childrens-teenage/"><span class="filter-name">Dinosaurs &amp; Prehistoric World (Children's / Teenage)</span><span class="badge badge-primary badge-pill filter-count">1</span></a>
# <a class="list-group-item list-group-item-action filter-item" data-category_id="1945" href="/catalogue/category/books/space-childrens-teenage/"><span class="filter-name">Space (Children's / Teenage)</span><span class="badge badge-primary badge-pill filter-count">1</span></a>
# <a class="list-group-item list-group-item-action filter-item" data-category_id="1947" href="/catalogue/category/books/football-soccer-childrens-teenage/"><span class="filter-name">Football / Soccer (Children's / Teenage)</span><span class="badge badge-primary badge-pill filter-count">1</span></a>
# <a class="list-group-item list-group-item-action filter-item" data-category_id="1970" href="/catalogue/category/books/coping-with-illness-specific-conditions/"><span class="filter-name">Coping With Illness &amp; Specific Conditions</span><span class="badge badge-primary badge-pill filter-count">1</span></a>
# <a class="list-group-item list-group-item-action filter-item" data-category_id="2081" href="/catalogue/category/books/political-leaders-leadership/"><span class="filter-name">Political Leaders &amp; Leadership</span><span class="badge badge-primary badge-pill filter-count">1</span></a>
# <a class="list-group-item list-group-item-action filter-item" data-category_id="2106" href="/catalogue/category/books/thrillers-childrens-teenage/"><span class="filter-name">Thrillers (Children's / Teenage)</span><span class="badge badge-primary badge-pill filter-count">3</span></a>
# <a class="list-group-item list-group-item-action filter-item" data-category_id="2112" href="/catalogue/category/books/cooking-food-childrens-teenage/"><span class="filter-name">Cooking &amp; Food (Children's / Teenage)</span><span class="badge badge-primary badge-pill filter-count">1</span></a>
# <a class="list-group-item list-group-item-action filter-item" data-category_id="2243" href="/catalogue/category/books/political-science-theory/"><span class="filter-name">Political Science &amp; Theory</span><span class="badge badge-primary badge-pill filter-count">2</span></a>
# <a class="list-group-item list-group-item-action filter-item" data-category_id="2259" href="/catalogue/category/books/adventure-stories-childrens-teenage/"><span class="filter-name">Adventure Stories (Children's / Teenage)</span><span class="badge badge-primary badge-pill filter-count">1</span></a>
# <a class="list-group-item list-group-item-action filter-item" data-category_id="2266" href="/catalogue/category/books/school-stories-childrens-teenage/"><span class="filter-name">School Stories (Children's / Teenage)</span><span class="badge badge-primary badge-pill filter-count">1</span></a>
# <a class="list-group-item list-group-item-action filter-item" data-category_id="2267" href="/catalogue/category/books/fantasy-magical-realism-childrens-teenage/"><span class="filter-name">Fantasy &amp; Magical Realism (Children's / Teenage)</span><span class="badge badge-primary badge-pill filter-count">2</span></a>
# <a class="list-group-item list-group-item-action filter-item" data-category_id="2540" href="/catalogue/category/books/international-relations/"><span class="filter-name">International Relations</span><span class="badge badge-primary badge-pill filter-count">1</span></a>
# ...
# <div class="w-100 d-flex justify-content-between align-items-center">
# <div class="stockrecord-prices">
# <span class="stockrecord-price-current">
#
#                     KES 1,250
#
#             </span>
# </div>
# </div>
# </div>
# </a>
# <form action="/basket/add/301216/" class="js-basket-add-form downloadable" data-api-action="/basket/api/add-product/" data-product-track-stock="True" method="post">
# <input name="product" type="hidden" value="301216"/>
# <input name="quantity" type="hidden" value="1"/>
# <button class="btn btn-light_accent mx-auto btn-block">Add to basket</button>
# <input name="csrfmiddlewaretoken" type="hidden" value="cU2lf588ijLELyEPqYYuNeRCQWfkeKs5otJVzRHRZZV0H0qTruflzrp6YFtnDEk9"/>
# </form>
# </div>
# </div>
# <div class="product-item d-flex col-6 col-sm-4 col-lg-3">
# <div class="card product-card">
# <div class="product-ribbon-sale">Sale</div>
# <a href="/catalogue/yinka-where-is-your-huzband-the-hilarious-and-heartfelt-romcom-everyone-is-talking-about-in-2022_321920/">
# <div class="product-card-img-container">
# <img alt="Yinka, Where is Your Huzband?: The hilarious and heartfelt romcom everyone is talking about in 2022" class="img-fluid card-img-top product-card-img" loading="lazy" src="/media/cache/56/9e/569eaae0f45b493d98690ac47f4bb541.jpg" srcset="/media/cache/56/9e/569eaae0f45b493d98690ac47f4bb541.jpg 1x, /media/cache/56/9e/569eaae0f45b493d98690ac47f4bb541@2x.jpg 2x"/>
# </div>
# <div class="card-body product-card-body mb-2">
# <div>
# <h5 class="card-title product-card-name">Yinka, Where is Your Huzband?: The hilarious and …</h5>
# <span class="text-muted small">Lizzie Damilola Blackburn</span>
# </div>
# <div class="w-100 d-flex justify-content-between align-items-center">
# <div class="stockrecord-prices">
# <span class="stockrecord-price-current">
#
#                     KES 1,521
#
#             </span>
# <span class="stockrecord-price-old">
#                 KES 1,690
#             </span>
# </div>
# </div>
# </div>
# </a>
# <form action="/basket/add/321920/" class="js-basket-add-form downloadable" data-api-action="/basket/api/add-product/" data-product-track-stock="True" method="post">
# <input name="product" type="hidden" value="321920"/>
# <input name="quantity" type="hidden" value="1"/>
# <button class="btn btn-light_accent mx-auto btn-block">Add to basket</button>
# <input name="csrfmiddlewaretoken" type="hidden" value="cU2lf588ijLELyEPqYYuNeRCQWfkeKs5otJVzRHRZZV0H0qTruflzrp6YFtnDEk9"/>
# </form>
# </div>
# </div>
# <div class="product-item d-flex col-6 col-sm-4 col-lg-3">
# <div class="card product-card">
# <a href="/catalogue/mans-search-for-meaning-random-us_273104/">
# <div class="product-card-img-container">
# <img alt="Man's search for meaning (Random-US)" class="img-fluid card-img-top product-card-img" loading="lazy" src="/media/cache/59/a5/59a5706f0197f1750fe920c6dce0adde.jpg" srcset="/media/cache/59/a5/59a5706f0197f1750fe920c6dce0adde.jpg 1x, /media/cache/59/a5/59a5706f0197f1750fe920c6dce0adde@2x.jpg 2x"/>
# </div>
# <div class="card-body product-card-body mb-2">
# <div>
# <h5 class="card-title product-card-name">Man's search for meaning (Random-US)</h5>
# <span class="text-muted small">Viktor E.Frankl</span>
# </div>
# <div class="w-100 d-flex justify-content-between align-items-center">
# <div class="stockrecord-prices">
# <span class="stockrecord-price-current">
#
#                     KES 1,850
#
#             </span>
# </div>
# </div>
# </div>
# </a>
# <form action="/basket/add/273104/" class="js-basket-add-form downloadable" data-api-action="/basket/api/add-product/" data-product-track-stock="True" method="post">
# <input name="product" type="hidden" value="273104"/>
# <input name="quantity" type="hidden" value="1"/>
# <button class="btn btn-light_accent mx-auto btn-block">Add to basket</button>
# <input name="csrfmiddlewaretoken" type="hidden" value="cU2lf588ijLELyEPqYYuNeRCQWfkeKs5otJVzRHRZZV0H0qTruflzrp6YFtnDEk9"/>
# </form>
# </div>
# </div>
# <div class="product-item d-flex col-6 col-sm-4 col-lg-3">
# <div class="card product-card">
# <a href="/catalogue/kamusi-ya-shule-za-msingi_14504/">
# <div class="product-card-img-container">
# <img alt="Kamusi ya Shule za Msingi" class="img-fluid card-img-top product-card-img" loading="lazy" src="/media/cache/d3/55/d355434dc2cd52db13df1970ea13e302.jpg" srcset="/media/cache/d3/55/d355434dc2cd52db13df1970ea13e302.jpg 1x, /media/cache/d3/55/d355434dc2cd52db13df1970ea13e302@2x.jpg 2x"/>
# </div>
# <div class="card-body product-card-body mb-2">
# <div>
# <h5 class="card-title product-card-name">Kamusi ya Shule za Msingi</h5>
# <span class="text-muted small">Kiango</span>
# </div>
# <div class="w-100 d-flex justify-content-between align-items-center">
# <div class="stockrecord-prices">
# <span class="stockrecord-price-current">
#
#                     KES 1,119
#
#             </span>
# </div>
# </div>
# </div>
# </a>
# <form action="/basket/add/14504/" class="js-basket-add-form downloadable" data-api-action="/basket/api/add-product/" data-product-track-stock="True" method="post">
# <input name="product" type="hidden" value="14504"/>
# <input name="quantity" type="hidden" value="1"/>
# <button class="btn btn-light_accent mx-auto btn-block">Add to basket</button>
# <input name="csrfmiddlewaretoken" type="hidden" value="cU2lf588ijLELyEPqYYuNeRCQWfkeKs5otJVzRHRZZV0H0qTruflzrp6YFtnDEk9"/>
# </form>
# </div>
# </div>
# <div class="product-item d-flex col-6 col-sm-4 col-lg-3">
# <div class="card product-card">
# <a href="/catalogue/think-big-unleashing-your-potential-for-exellence_11997/">
# <div class="product-card-img-container">
# <img alt="Think Big : Unleashing your potential for exellence" class="img-fluid card-img-top product-card-img" loading="lazy" src="/media/cache/9b/84/9b84a59beb6fcfa9e59a698817e240b5.jpg" srcset="/media/cache/9b/84/9b84a59beb6fcfa9e59a698817e240b5.jpg 1x, /media/cache/9b/84/9b84a59beb6fcfa9e59a698817e240b5@2x.jpg 2x"/>
# </div>
# <div class="card-body product-card-body mb-2">
# <div>
# <h5 class="card-title product-card-name">Think Big : Unleashing your potential for exellence</h5>
# <span class="text-muted small">Ben Carson M.D.</span>
# </div>
# <div class="w-100 d-flex justify-content-between align-items-center">
# <div class="stockrecord-prices">
# <span class="stockrecord-price-current">
#
#                     KES 590
#
#             </span>
# </div>
# </div>
# </div>
# </a>
# <form action="/basket/add/11997/" class="js-basket-add-form downloadable" data-api-action="/basket/api/add-product/" data-product-track-stock="True" method="post">
# <input name="product" type="hidden" value="11997"/>
# <input name="quantity" type="hidden" value="1"/>
# <button class="btn btn-light_accent mx-auto btn-block">Add to basket</button>
# <input name="csrfmiddlewaretoken" type="hidden" value="cU2lf588ijLELyEPqYYuNeRCQWfkeKs5otJVzRHRZZV0H0qTruflzrp6YFtnDEk9"/>
# </form>
# </div>
# </div>
# <div class="product-item d-flex col-6 col-sm-4 col-lg-3">
# <div class="card product-card">
# <div class="product-ribbon-sale">Sale</div>
# <a href="/catalogue/unbowed-one-womans-story_12188/">
# <div class="product-card-img-container">
# <img alt="Unbowed One woman's Story" class="img-fluid card-img-top product-card-img" loading="lazy" src="/media/cache/4b/ef/4bef9b5f0c3a62ce05a7c99f39abd0db.jpg" srcset="/media/cache/4b/ef/4bef9b5f0c3a62ce05a7c99f39abd0db.jpg 1x, /media/cache/4b/ef/4bef9b5f0c3a62ce05a7c99f39abd0db@2x.jpg 2x"/>
# </div>
# <div class="card-body product-card-body mb-2">
# <div>
# <h5 class="card-title product-card-name">Unbowed One woman's Story</h5>
# <span class="text-muted small">Wangari Maathai</span>
# </div>
# <div class="w-100 d-flex justify-content-between align-items-center">
# <div class="stockrecord-prices">
# <span class="stockrecord-price-current">
#
#                     KES 1,035
#
#             </span>
# <span class="stockrecord-price-old">
#                 KES 1,150
#             </span>
# </div>
# <div class="product-card--rating small text-muted">
#                             5 <div class="catalogue-reviews-star active"><span class="star-filled">
# <svg class="icon icon-star" role="presentation">
# <use href="/static/regulus_oscar/svg/icons.8a287fcd2acc.svg#star"></use>
# </svg>
# </span></div>
# </div>
# </div>
# </div>
# </a>
# <form action="/basket/add/12188/" class="js-basket-add-form downloadable" data-api-action="/basket/api/add-product/" data-product-track-stock="True" method="post">
# <input name="product" type="hidden" value="12188"/>
# <input name="quantity" type="hidden" value="1"/>
# <button class="btn btn-light_accent mx-auto btn-block">Add to basket</button>
# <input name="csrfmiddlewaretoken" type="hidden" value="cU2lf588ijLELyEPqYYuNeRCQWfkeKs5otJVzRHRZZV0H0qTruflzrp6YFtnDEk9"/>
# </form>
# </div>
# </div>
# <div class="product-item d-flex col-6 col-sm-4 col-lg-3">
# <div class="card product-card">
# <a href="/catalogue/golden-bells-new-edition_14915/">
# <div class="product-card-img-container">
# <img alt="Golden Bells New Edition" class="img-fluid card-img-top product-card-img" loading="lazy" src="/media/cache/f1/ac/f1ac48180c9eb7c17253a34cf9e2f2c9.jpg" srcset="/media/cache/f1/ac/f1ac48180c9eb7c17253a34cf9e2f2c9.jpg 1x, /media/cache/f1/ac/f1ac48180c9eb7c17253a34cf9e2f2c9@2x.jpg 2x"/>
# </div>
# <div class="card-body product-card-body mb-2">
# <div>
# <h5 class="card-title product-card-name">Golden Bells New Edition</h5>
# <span class="text-muted small">Scripture Union of Kenya</span>
# </div>
# <div class="w-100 d-flex justify-content-between align-items-center">
# <div class="stockrecord-prices">
# <span class="stockrecord-price-current">
#
#                     KES 450
#
#             </span>
# </div>
# <div class="product-card--rating small text-muted">
#                             5 <div class="catalogue-reviews-star active"><span class="star-filled">
# <svg class="icon icon-star" role="presentation">
# <use href="/static/regulus_oscar/svg/icons.8a287fcd2acc.svg#star"></use>
# </svg>
# </span></div>
# </div>
# </div>
# </div>
# </a>
# <form action="/basket/add/14915/" class="js-basket-add-form downloadable" data-api-action="/basket/api/add-product/" data-product-track-stock="True" method="post">
# <input name="product" type="hidden" value="14915"/>
# <input name="quantity" type="hidden" value="1"/>
# <button class="btn btn-light_accent mx-auto btn-block">Add to basket</button>
# <input name="csrfmiddlewaretoken" type="hidden" value="cU2lf588ijLELyEPqYYuNeRCQWfkeKs5otJVzRHRZZV0H0qTruflzrp6YFtnDEk9"/>
# </form>
# </div>
# </div>
# </div>
# <ul class="pagination page-paginator">
# <li class="page-item page-paginator-item active">
# <a class="page-link page-paginator-link" href="?page=1">1 <span class="sr-only">(current)</span></a>
# </li>
# <li class="page-item page-paginator-item">
# <a class="page-link page-paginator-link" href="?page=2">2 <span class="sr-only">(current)</span></a>
# </li>
# <li class="page-item page-paginator-item">
# <a class="page-link page-paginator-link" href="?page=3">3 <span class="sr-only">(current)</span></a>
# </li>
# <li class="page-item page-paginator-item disabled"><a class="page-link page-paginator-link">…</a></li>
# <li class="page-item page-paginator-item"><a class="page-link page-paginator-link" href="?page=166">166</a></li>
# <li class="page-item page-paginator-item"><a class="page-link page-paginator-link" href="?page=2">Next</a></li>
# </ul>
# </section>
# </div>
# </div>
# </div>
# </div><!-- /row -->
# </div><!-- /container -->
# </main>
# <footer class="page-footer">
# <div class="container">
# <div class="row">
# <div class="col-6 col-lg-3 order-1">
# <section class="page-footer-section">
# <h3>Customer service</h3>
# <ul class="link-menu link-menu-footer_customer_service">
# <li><a href="https://textbookcentre.com/contact/">Contact Us</a>
# </li>
# <li><a href="https://textbookcentre.com/faq/">Frequently asked questions</a>
# </li>
# <li><a href="/accounts/">My account</a>
# </li>
# </ul>
# </section>
# </div>
# <div class="col-6 col-lg-3 order-2">
# <section class="page-footer-section">
# <h3>Shop with us</h3>
# <ul class="link-menu link-menu-footer_shop_with_us">
# <li><a href="https://textbookcentre.com/shipping-refunds/">Shipping and refunds</a>
# </li>
# <li><a href="https://textbookcentre.com/privacy-policy/">Privacy policy</a>
# </li>
# </ul>
# </section>
# </div>
# <div class="col-6 col-lg-3 order-3">
# <section class="page-footer-section">
# <h3>About us</h3>
# <ul class="link-menu link-menu-about_us">
# <li><a href="https://textbookcentre.com/our-story/">Our story</a>
# </li>
# <li><a href="https://textbookcentre.com/careers/">Careers</a>
# </li>
# <li><a href="https://tbc.ongea.io/">TBC Whistleblowing Portal</a>
# </li>
# </ul>
# </section>
# </div>
# <div class="col-lg-3 order-0 order-lg-4">
# <section class="page-footer-section">
# <ul class="page-social">
# <li class="page-social__item facebook"><a href="https://www.facebook.com/textbookcentre" target="_blank">
# <svg class="icon icon-facebook" role="presentation">
# <use href="/static/regulus_oscar/svg/icons.8a287fcd2acc.svg#facebook"></use>
# </svg>
# </a></li>
# <li class="page-social__item twitter"><a href="https://twitter.com/TextBookCentre" target="_blank">
# <svg class="icon icon-twitter" role="presentation">
# <use href="/static/regulus_oscar/svg/icons.8a287fcd2acc.svg#twitter"></use>
# </svg>
# </a></li>
# <li class="page-social__item linkedin"><a href="https://www.linkedin.com/company/text-book-centre-ltd/" target="_blank">
# <svg class="icon icon-linkedin" role="presentation">
# <use href="/static/regulus_oscar/svg/icons.8a287fcd2acc.svg#linkedin"></use>
# </svg>
# </a></li>
# <li class="page-social__item instagram"><a href="https://instagram.com/textbookcentre" target="_blank">
# <svg class="icon icon-instagram" role="presentation">
# <use href="/static/regulus_oscar/svg/icons.8a287fcd2acc.svg#instagram"></use>
# </svg>
# </a></li>
# </ul>
# </section>
# </div>
# </div>
# <p class="page-footer-copyright">© 2023 Text Book Centre Ltd. Crafted by <a href="https://regulusweb.com" target="_blank">Regulus</a>.
# </p>
# </div>
# <div class="contact-whatsapp-cta">
# <h4><a href="https://wa.me/+254114509617">
# <svg class="icon icon-whatsapp" role="presentation">
# <use href="/static/regulus_oscar/svg/icons.8a287fcd2acc.svg#whatsapp"></use>
# </svg>
# <span class="d-none d-md-inline"> Need help?</span></a></h4>
# </div>
# </footer>
# </div>
# <div id="toast-container"></div>
# <script id="page_info" type="application/json">{"sentry_dsn": "https://7f750a1e01284323b7657199adf421f8@sentry.io/1473693", "needs_reload": null, "recaptcha_site_key": "6LdYKSkaAAAAAMGRLMZPlN77XaGMK_h3Z99uHbF7", "google_analytics_data": {"id": "G-R71JEH505V", "user_id": null}, "facebook_pixel_data": {"id": "105414563161506"}}</script>
# <script src="/static/jquery.min.00727d1d5d9c.js"></script>
# <script src="/static/webpack_bundles/main.7d0af9fedc91.js" type="text/javascript"></script>
# <script src="/static/webpack_bundles/promotions.d0fceb794391.js" type="text/javascript"></script>
# <div class="js-promotions-modal basket-modal modal fade" data-disable-modal-cookie-data='{"name": "disable_promotions_modal_1678950334662583", "value": "1", "options": {"secure": true, "expires": 30.0}}' role="dialog" tabindex="-1">
# <div class="modal-dialog modal-dialog-centered modal-dialog-scrollable modal-lg" role="document">
# <div class="modal-content">
# <div class="modal-body">
# <button class="close" data-dismiss="modal">×</button>
# <div class="container">
# <section class="block block-carousel mb-0">
# <div class="carousel slide" data-ride="carousel" id="carousel-8cf6872b-885a-47d8-b080-85cf88a4e94f">
# <ol class="carousel-indicators">
# <li class="active" data-slide-to="0" data-target="#carousel-8cf6872b-885a-47d8-b080-85cf88a4e94f"></li>
# </ol>
# <div class="carousel-inner">
# <div class="carousel-item active">
# <a href="https://bit.ly/tbcxjava_mar" title="Browse Now!!">
# <img alt="BOTM_MAR.png" class="img-fluid d-none d-lg-block mx-auto" height="1140" src="/media/images/BOTM_MAR.width-1140.png" width="1140">
# <img alt="BOTM_MAR.png" class="img-fluid d-block d-lg-none mx-auto" height="720" src="/media/images/BOTM_MAR.width-720.png" width="720"/>
# <div class="carousel-caption">
# <p>Browse Now!!</p>
# </div>
# </img></a>
# </div>
# </div>
# </div>
# </section>
# </div>
# </div>
# </div>
# </div>
# </div>
# </body>
# </html>

# %% [markdown]
# ### Results

# %%
results = soup.find_all('div', {'class':'product-item d-flex col-6 col-sm-4 col-lg-3'})

# %%
len(results)
# Out:
# 40

# %%
results[0]
# Out:
# <div class="product-item d-flex col-6 col-sm-4 col-lg-3">
# <div class="card product-card">
# <a href="/catalogue/atomic-habits-easy-and-proven-way-to-build-good-habits-and-break-bad-ones_27294/">
# <div class="product-card-img-container">
# <img alt="Atomic Habits: Easy and proven way to build good habits and break bad ones" class="img-fluid card-img-top product-card-img" loading="lazy" src="/media/cache/cf/88/cf88d9d5f84378e2784d61e2002853e7.jpg" srcset="/media/cache/cf/88/cf88d9d5f84378e2784d61e2002853e7.jpg 1x, /media/cache/cf/88/cf88d9d5f84378e2784d61e2002853e7@2x.jpg 2x"/>
# </div>
# <div class="card-body product-card-body mb-2">
# <div>
# <h5 class="card-title product-card-name">Atomic Habits: Easy and proven way to build …</h5>
# <span class="text-muted small">James Clear</span>
# </div>
# <div class="w-100 d-flex justify-content-between align-items-center">
# <div class="stockrecord-prices">
# <span class="stockrecord-price-current">
#
#                     KES 1,850
#
#             </span>
# </div>
# <div class="product-card--rating small text-muted">
#                             5 <div class="catalogue-reviews-star active"><span class="star-filled">
# <svg class="icon icon-star" role="presentation">
# <use href="/static/regulus_oscar/svg/icons.8a287fcd2acc.svg#star"></use>
# </svg>
# </span></div>
# </div>
# </div>
# </div>
# </a>
# <form action="/basket/add/27294/" class="js-basket-add-form downloadable" data-api-action="/basket/api/add-product/" data-product-track-stock="True" method="post">
# <input name="product" type="hidden" value="27294"/>
# <input name="quantity" type="hidden" value="1"/>
# <button class="btn btn-light_accent mx-auto btn-block">Add to basket</button>
# <input name="csrfmiddlewaretoken" type="hidden" value="cU2lf588ijLELyEPqYYuNeRCQWfkeKs5otJVzRHRZZV0H0qTruflzrp6YFtnDEk9"/>
# </form>
# </div>
# </div>

# %% [markdown]
# ### Target Data
# * *Book Name*
# * *Author*
# * *Review Rating*
# * *Review Count*
# * *Product Link*
# * *Book Details*

# %% [markdown]
# ### Book Name

# %%
results[0].find('h5', {'class': 'card-title product-card-name'}).get_text()
# Out:
# 'Atomic Habits: Easy and proven way to build …'

# %% [markdown]
# ### Author

# %%
results[0].find('span', {'class':'text-muted small'})
# Out:
# <span class="text-muted small">James Clear</span>

# %% [markdown]
# ### Price

# %%
results[0].find('span', {'class':'stockrecord-price-current'}).get_text().strip()
# Out:
# 'KES 1,850'

# %% [markdown]
# ### Review Rating

# %%
results[0].find('div', {'class':'product-card--rating small text-muted'}).get_text().strip()
# Out:
# '5'

# %% [markdown]
# ### All Columns

# %%
book_name = []

book_author = []

book_price = []

book_rating = []

for result in results:
    
#Name
    try:
        book_name.append(result.find('h5', {'class':'card-title product-card-name'}).get_text())
    except:
        book_name.append('nan')
        
#author

    try:
        book_author.append(result.find('span',{'class':'text-muted small'}).get_text())
    except:
        book_author.append(np.nan)

#price

    try:    
        book_price.append(result.find('span', {'class':'stockrecord-price-current'}).get_text().strip())
    except:
        book_price.append(np.nan)
        
#rating

    try:    
        book_rating.append(result.find('div', {'class':'product-card--rating small text-muted'}).get_text().strip())
    except:
        book_rating.append(np.nan)

# %% [markdown]
# ### DataFrame

# %%
book_overview = pd.DataFrame({'Name': book_name,'author': book_author,'price': book_price,'rating': book_rating})

# %%
book_overview
# Out:
#                                                  Name  \
# 0       Atomic Habits: Easy and proven way to build …
# 1                                The 48 Laws of Power
# 2                  8 Rules of Love: How to Find it, …
# 3                                     Good News Bible
# 4                 Across The Bridge by Mwangi Gicheru
# 5   The Light We Carry: Overcoming In Uncertain Ti...
# 6              Outliers: The Story of Success (Small)
# 7                               Kamusi ya Karne ya 21
# 8          It Ends With Us: The emotional #1 Sunday …
# 9                      Vintage Classics: Little Women
# 10              Kamusi ya Methali za Kiswahili (EAEP)
# 11        Ikigai: The Japanese Secret to a Long and …
# 12         The 5 AM Club: Own Your Morning. Elevate …
# 13                                  12 Rules for Life
# 14               The Power of Habit: Why we do what …
# 15                                      The Alchemist
# 16                                Making of a Manager
# 17            Black Girls Must Die Exhausted: A Novel
# 18  Best of Whispers: Politics, Family and Society...
# 19        Presidents' Pressman: A Memoir (Lee Njiru).
# 20                                              SPARE
# 21  Secret Lives of Baba Segi's Wives (Serpent's T...
# 22                          Ladybird 1A: Play With Us
# 23                                       Dare to Lead
# 24  Ross and Wilson Anatomy and Physiology in Heal...
# 25                                             Wahala
# 26                                The Havoc of Choice
# 27                Should I? Your Question About Money
# 28  GRIT: Why passion and resilience are the secre...
# 29              How to Stop Worrying and Start living
# 30                     Emotional Intelligence (Small)
# 31                                      Girl was Mine
# 32     Leadership Wisdom from the Monk who sold his …
# 33    The 7 Habits of Highly Effective People (B66KS)
# 34  Yinka, Where is Your Huzband?: The hilarious a...
# 35               Man's search for meaning (Random-US)
# 36                          Kamusi ya Shule za Msingi
# 37  Think Big : Unleashing your potential for exel...
# 38                          Unbowed One woman's Story
# 39                           Golden Bells New Edition
#
#                        author      price rating
# 0                 James Clear  KES 1,850      5
# 1               Robert Greene  KES 2,450      5
# 2                  JAY SHETTY  KES 2,350    NaN
# 3               Bible society    KES 986      4
# 4              Mwangi Gicheru    KES 754      5
# 5              Michelle Obama  KES 2,750    NaN
# 6            Malcolm Gladwell    KES 890      5
# 7                    Longhorn  KES 1,250      5
# 8              Colleen Hoover  KES 1,350      5
# 9           Louisa May Alcott    KES 350    NaN
# 10                        NaN    KES 796    NaN
# 11  Hector Garcia , Francesc…  KES 1,990      5
# 12               Robin Sharma  KES 2,490      5
# 13         Jordan B. Peterson  KES 1,190      5
# 14             Charles Duhigg  KES 1,150      5
# 15               Paulo Coelho    KES 990    4.5
# 16                       Zhou  KES 1,650    NaN
# 17                Jayne Allen  KES 1,490    NaN
# 18              Wahome Mutahi    KES 650    4.8
# 19                  Lee Njiru  KES 2,320      4
# 20  Prince Harry, Duke of Su…  KES 3,650    NaN
# 21              Lola Shoneyin  KES 1,305      5
# 22                 W . Murray    KES 200    NaN
# 23                      Brown  KES 1,690    NaN
# 24  Anne Waugh , Allison Gra…  KES 4,400    NaN
# 25                  Nikki May  KES 1,395    NaN
# 26           Wanjiru Koinange  KES 1,530    4.9
# 27              Florence Bett  KES 1,200    NaN
# 28           Angela Duckworth  KES 1,350    NaN
# 29             Carnegie, Dale    KES 550    NaN
# 30             Daniel Goleman  KES 1,550      5
# 31                    Karanja    KES 692      5
# 32               Robin Sharma    KES 990    NaN
# 33       Simon & Schuster Ltd  KES 1,250    NaN
# 34  Lizzie Damilola Blackburn  KES 1,521    NaN
# 35            Viktor E.Frankl  KES 1,850    NaN
# 36                     Kiango  KES 1,119    NaN
# 37            Ben Carson M.D.    KES 590    NaN
# 38            Wangari Maathai  KES 1,035      5
# 39   Scripture Union of Kenya    KES 450      5

# %%
### Export to excel

book_overview.to_excel('book_overview.xlsx', index=False)

# %%
## Pagination - Scrapping multiple pages

book_name = []
book_author = []
book_price = []
book_rating = []

for i in range(1, 117):

    #website
    website = "https://textbookcentre.com/catalogue/category/books/?page=" + str(i)

    #request
    response = requests.get(website)

    #soup
    soup = BeautifulSoup(response.content, 'html.parser')

    #results
    results = soup.find_all('div', {'class':'product-item d-flex col-6 col-sm-4 col-lg-3'})

#loop

    for result in results:
    #Name
        try:
            book_name.append(result.find('h5', {'class':'card-title product-card-name'}).get_text())
        except:
            book_name.append('nan')
            
    #author

        try:
            book_author.append(result.find('span',{'class':'text-muted small'}).get_text())
        except:
            book_author.append(np.nan)

    #price

        try:    
            book_price.append(result.find('span', {'class':'stockrecord-price-current'}).get_text().strip())
        except:
            book_price.append(np.nan)
            
    #rating

        try:    
            book_rating.append(result.find('div', {'class':'product-card--rating small text-muted'}).get_text().strip())
        except:
            book_rating.append(np.nan)
    
book_overview = pd.DataFrame({'Name': book_name,'author': book_author,'price': book_price,'rating': book_rating})

# %%
book_overview
# Out:
#                                                    Name          author  \
# 0         Atomic Habits: Easy and proven way to build …     James Clear
# 1                                  The 48 Laws of Power   Robert Greene
# 2                    8 Rules of Love: How to Find it, …      JAY SHETTY
# 3                                       Good News Bible   Bible society
# 4                   Across The Bridge by Mwangi Gicheru  Mwangi Gicheru
# ...                                                 ...             ...
# 4635              Look Inside What Happens When You Eat   Stefano Gatti
# 4636  Disney Tangled The Series Mosaic Sticker by Nu...             NaN
# 4637         Bug Club Guided Non Fiction Year 1 Green …       Llewellyn
# 4638  Let's Celebrate - Read It Yourself with Ladybi...         Randall
# 4639                                      Halloween Art             NaN
#
#           price rating
# 0     KES 1,850      5
# 1     KES 2,450      5
# 2     KES 2,350    NaN
# 3       KES 986      4
# 4       KES 754      5
# ...         ...    ...
# 4635  KES 1,290    NaN
# 4636    KES 350    NaN
# 4637    KES 450    NaN
# 4638    KES 200    NaN
# 4639    KES 690    NaN
#
# [4640 rows x 4 columns]

# %%
book_overview.to_excel('book_overview2.xlsx', index=False)
